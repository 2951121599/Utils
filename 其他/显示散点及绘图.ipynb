# %%
import numpy as np
import matplotlib.pyplot as plt

X = 2*np.random.rand(100, 1) # rand是生成平均分布的浮点数
y = 4 + 3*X + np.random.randn(100, 1) # randn是生成正态分布的浮点数

plt.scatter(X, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0.41942,0.40135,0.37372,0.34712,0.31433,0.28592,0.25494,0.19891,0.16018,0.13359,0.10854,0.08117,0.02695,-0.02211,-0.06342,-0.09182,-0.10138,-0.11945,0.41839,0.40909,0.38482,0.36261,0.33834,0.3151,0.28256,0.23944,0.19891,0.14727,0.1137,0.05612,0.01739,-0.01178,-0.04019,-0.06446,-0.08769,-0.12126,0.41839,0.39877,0.38147,0.35487,0.33318,0.30736,0.27999,0.24797,0.21544,0.17154,0.12662,0.06388,0.01404,-0.01281,-0.03347,-0.0549,-0.08511,-0.12203,0.41839,0.39773,0.36003,0.32801,0.29625,0.26965,0.22318,0.17567,0.13358,0.09305,0.0631,0.03366,-0.00842,-0.03502,-0.05826,-0.07375,-0.09699,-0.12281])
y = np.array([0.34852,0.31032,0.25657,0.20917,0.14763,0.11935,0.09389,0.06067,0.05149,0.0416,0.03241,0.00625,-0.0291,-0.03827,-0.07858,-0.11607,-0.15144,-0.18186,0.32022,0.28202,0.24665,0.21129,0.16885,0.12641,0.07477,0.03942,0.01609,0.01116,-0.00509,-0.03619,-0.05952,-0.08781,-0.12317,-0.14438,-0.1564,-0.20803,0.38602,0.33863,0.30609,0.24667,0.22121,0.18797,0.15968,0.1222,0.10099,0.08898,0.0607,0.03244,0.00628,-0.01493,-0.08992,-0.06656,-0.10404,-0.16063,0.29404,0.24665,0.18582,0.12216,0.08679,0.06063,0.0274,0.02035,0.00622,-0.00296,-0.01497,-0.01212,-0.04536,-0.06869,-0.09698,-0.109,-0.14224,-0.17478])

plt.scatter(x, y)
plt.show()

# %%
import sklearn.linear_model as lm
# 基于梯度下降理论 找到最优w0与w1 使得loss取最小值
w0 = 1
w1 = 1
times = 1000
lrate = 0.01
for i in range(times):
    # 通过偏导公式求两方向上的偏导数
    d0 = (w0 + w1 * x - y).sum()
    d1 = (x * (w0 + w1 * x - y)).sum()
    # 更新w0与w1
    w0 = w0 - lrate * d0
    w1 = w1 - lrate * d1
print(w0, w1)
# Out:
# -0.06743046096550968 0.7967219965646186
